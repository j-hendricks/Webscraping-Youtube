# %%
import requests
from bs4 import BeautifulSoup as bs
import json
import re
import splinter
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import datetime

# %%
# Setup splinter
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# visit wikipedia page to find top 50 Youtubers
url = "https://en.wikipedia.org/wiki/List_of_most-subscribed_YouTube_channels"
browser.visit(url)

# %%
# use Beautiful soup to parse html
html = browser.html
soup = bs(html, 'html.parser')

# %%
# we want first table of class "wikitable", so use find function
table = soup.find('table', class_="wikitable")

# %%
# list of top 50 Youtube channels
channels = []

# list of all rows in table
rows = table.find('tbody').find_all('tr')

# for each row, add the text in the first cell to channels
for row in rows:
    channel = row.find('td').text #first cell holds the channel name
    channels.append(channel.strip()) #call strip because of \n at the end of each text

# %%
# find all the tags that contain a link to Youtube page
tags_with_links = table.find_all('a', class_='external text')

# %%
# make list of YouTube links
links = []

for tag in tags_with_links:
    links.append(tag.get('href'))

# %%
# the final link is a dud, so we splice that out
links = links[0:len(links)-1]

# %%
# check that links variable is working properly
for link in links:
    print(link)
# Out:
# https://www.youtube.com/channel/UCq-Fj5jknLsUf-MWSy4_brA
# https://www.youtube.com/channel/UCbCmjCuTUZos6Inko4u57UQ
# https://www.youtube.com/channel/UCpEhnqL0y41EpW2TvWAHD7Q
# https://youtube.com/user/PewDiePie
# https://www.youtube.com/channel/UCX6OQ3DkcsbYNE6H8uQQuVA
# https://www.youtube.com/channel/UCk8GzjMOrta8yxDcKfylJYw
# https://www.youtube.com/channel/UCJplp5SjeGSdVdwsfb9Q7lQ
# https://www.youtube.com/channel/UCJ5v_MCY6GNUBTO8-D3XoAg
# https://www.youtube.com/channel/UCFFbwnve3yF62-tVXkTyHqg
# https://www.youtube.com/channel/UCvlE5gTbOvjiolFlEm-c_Ow
# https://www.youtube.com/channel/UCOmHUn--16B90oW2L6FRR3A
# https://www.youtube.com/channel/UC295-Dw_tDNtZXFeAPAW6Aw
# https://www.youtube.com/channel/UCyoXW-Dse7fURq30EWl_CUA
# https://www.youtube.com/channel/UC6-F5tO8uklgE9Zy8IvbdFw
# https://www.youtube.com/channel/UCLkAepWjdylmXSltofFvsYQ
# https://www.youtube.com/channel/UCIwFjwMjI0y7PDBVEO9-bkQ
# https://www.youtube.com/channel/UC3IZKseVpdzPSBaWxBxundA
# https://www.youtube.com/channel/UCffDXn7ycAzwL2LDlbyWOTw
# https://www.youtube.com/channel/UCppHT7SZKKvar4Oc9J4oljQ
# https://www.youtube.com/channel/UCP6uH_XlsxrXwZQ4DlqbqPg
# https://www.youtube.com/channel/UCcdwLMPsaU2ezNSJU1nFoBQ
# https://www.youtube.com/channel/UCRijo3ddMTht_IHyNSNXpNQ
# https://www.youtube.com/channel/UCBnZ16ahKA2DZ_T5W0FPUXg
# https://www.youtube.com/channel/UC3gNmTGu-TTbFPpfSs5kNkg
# https://www.youtube.com/channel/UCEdvpU2pFRCVqU6yIPyTpMQ
# https://www.youtube.com/channel/UC55IWqFLDH1Xp7iu1_xknRA
# https://www.youtube.com/channel/UC22nIfOTM7KLIQuFGMKzQbg
# https://www.youtube.com/channel/UCfM3zsQsOnfWNUppiycmBuw
# https://www.youtube.com/channel/UCt4t-jeY85JegMlZ-E5UWtA
# https://www.youtube.com/channel/UCJrDMFOdv1I2k8n9oK_V21w
# https://www.youtube.com/channel/UCaayLD9i5x4MmIoVZxXSv_g
# https://www.youtube.com/channel/UC56gTxNs4f9xZ7Pa2i5xNzg
# https://www.youtube.com/channel/UC0C-w0YjGpqDXGB8IHb662A
# https://www.youtube.com/channel/UCK1i2UviaXLUNrZlAFpw_jA
# https://www.youtube.com/channel/UC9CoOnJkIBMdeijd9qYoT_g
# https://www.youtube.com/channel/UC4NALVCmcmL5ntpV0thoH6w
# https://www.youtube.com/channel/UCbTLwN10NoCU4WDzLf1JMOA
# https://www.youtube.com/channel/UCqECaJ8Gagnn7YCbPEzWH6g
# https://www.youtube.com/channel/UCRx3mKNUdl8QE06nEug7p6Q
# https://www.youtube.com/channel/UCiGm_E4ZwYSHV3bcW1pnSeQ
# https://www.youtube.com/channel/UCYiGq8XF7YQD00x7wAd62Zg
# https://www.youtube.com/channel/UC1ciY6kR3yj3kaKZ6R7ewAg
# https://www.youtube.com/channel/UCYWOjHweP2V-8kGKmmAmQJQ
# https://www.youtube.com/channel/UCV4xOVpbcV8SdueDCOxLXtQ
# https://www.youtube.com/channel/UCV306eHqgo0LvBf3Mh36AHg
# https://www.youtube.com/channel/UC4rlAVgAK0SGk-yTfe48Qpw
# https://www.youtube.com/channel/UC3KQ5GWANYF8lChqjZpXsQw
# https://www.youtube.com/channel/UCZJ7m7EnCNodqnu5SAtg8eQ
# https://www.youtube.com/channel/UCj0O6W8yDuLg3iraAXKgCrQ
# https://www.youtube.com/channel/UCYvmuw-JtVrTZQ-7Y4kd63Q

# %%
# make dictionary that pairs each channel with its web link
channel_and_link = dict(zip(channels,links))

# %%
# list holding all of the video information, where each element is a dictionary holding info for one video
video_info_list = []

# loop through each channel and go to webapge to scrape data
for channel, link in channel_and_link.items():
    
    
    # visit each page
    browser.visit(link+"/videos")
    
    # get html
    html = browser.html
    
    # use Beautiful Soup to parse html
    soup = bs(html, 'html.parser')
    
    # search html for "a" tag with video-title as the id - this provides the tag holding the title
    titles = soup.find_all("a", id='video-title', 
                           class_ = 'yt-simple-endpoint style-scope ytd-grid-video-renderer')
           
    # search html for "span" tag of specified class - this provides the tags holding 
    # the number of views and the time the video was posted
    views_and_time = soup.find_all("span", class_="style-scope ytd-grid-video-renderer")
    
    # hold all video titles
    video_titles = []
    
    for title in titles:
        
        title_as_text = title.text
        
        video_titles.append(title_as_text)
    
    
    
    start_index = 0
    
    finish_index = len(views_and_time)
    
    # holds all of the views
    views = []
    
    # holds all of the post times
    post_time = []
    
    for index in range(start_index, finish_index):
        
        # this is the element we will add to a list
        target_element = views_and_time[index].text
        
        # if the index is even, then it must be views information
        if (index % 2 == 0):
            views.append(target_element)
    
        # otherwise, index is odd, meaning it is post-time information
        else:
            post_time.append(target_element)
    
    print("Titles Length:",len(video_titles))
    print("Views Length",len(views))
    print("Post-Time Length:",len(post_time))
    
    
    # with all the information needed, loop through index of the lists, where each index represents
    # a video
    for i in range(0, len(video_titles)):
       
        # indexError is likely because of the variability in the html pages 
        try: 
            
            # sometimes no information is scraped, so make sure that there is at least one video to add
            if ( ( len(video_titles[i]) > 0 ) & ( len(views[i]) > 0 ) & ( len(post_time[i]) > 0 ) ):
                
                video_info = {
                    "Channel": channel,
                    "Title": video_titles[i],
                    "Views": views[i],
                    "Post-Time": post_time[i]
                }

                # add video to list of videos
                video_info_list.append(video_info)
        
        # catch IndexErrors and continue 
        except IndexError:
            print("Expected Error Occured. Moving on...")
# Out:
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 0
# Views Length 0
# Post-Time Length: 0
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 29
# Post-Time Length: 29
# Expected Error Occured. Moving on...
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 0
# Views Length 0
# Post-Time Length: 0
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 29
# Post-Time Length: 28
# Expected Error Occured. Moving on...
# Expected Error Occured. Moving on...
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 0
# Views Length 0
# Post-Time Length: 0
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 29
# Expected Error Occured. Moving on...
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 15
# Post-Time Length: 15
# Expected Error Occured. Moving on...
# Expected Error Occured. Moving on...
# Expected Error Occured. Moving on...
# Expected Error Occured. Moving on...
# Expected Error Occured. Moving on...
# Expected Error Occured. Moving on...
# Expected Error Occured. Moving on...
# Expected Error Occured. Moving on...
# Expected Error Occured. Moving on...
# Expected Error Occured. Moving on...
# Expected Error Occured. Moving on...
# Expected Error Occured. Moving on...
# Expected Error Occured. Moving on...
# Expected Error Occured. Moving on...
# Expected Error Occured. Moving on...
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 29
# Expected Error Occured. Moving on...
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30
# Titles Length: 30
# Views Length 30
# Post-Time Length: 30

# %%
video_info_list
# Out:
# [{'Channel': 'T-Series',
#   'Title': 'Tu Banke Hawa - Dhokha: Round D Corner | R. Madhvan, Khushalli Kumar |Jubin Nautiyal | Gourov,Devshi',
#   'Views': '754K views',
#   'Post-Time': '12 hours ago'},
#  {'Channel': 'T-Series',
#   'Title': 'Vikram In Action: Vikram Vedha | Saif Ali Khan as Vikram | Behind The Scenes | Hindi Movie 2022',
#   'Views': '737K views',
#   'Post-Time': '15 hours ago'},
#  {'Channel': 'T-Series',
#   'Title': 'Thank God (Trailer Screening) Ft. Sidharth Malhotra | Indra Kumar | Bhushan Kumar',
#   'Views': '219K views',
#   'Post-Time': '17 hours ago'},
#  {'Channel': 'T-Series',
#   'Title': 'Dhokha: Round D Corner | Dialogue Promo 01: Terrorist Chhupa Hua Hai | 23rd Sep 2022 | Bhushan Kumar',
#   'Views': '117K views',
#   'Post-Time': '1 day ago'},
#  {'Channel': 'T-Series',
#   'Title': '#KatrinaKaif #AkshayKumar - Teri Galliyon Se #sadstatus #shorts',
#   'Views': '178K views',
#   'Post-Time': '1 day ago'},
#  {'Channel': 'T-Series',
#   'Title': 'Behind The Scenes: Baarish Mein Tum | Gauahar Khan, Zaid Darbar | Adil Shaikh',
#   'Views': '148K views',
#   'Post-Time': '1 day ago'},
#  {'Channel': 'T-Series',
#   'Title': 'Dheere Dheere Se - Old vs New Song Status | #lovestatus #shorts',
#   'Views': '285K views',
#   'Post-Time': '2 days ago'},
#  {'Channel': 'T-Series',
#   'Title': 'Botal Mein Jahar: Woh 3 Din | Sanjay Mishra | Raaj Aashoo| Pancham Singh | Chandan Roy |Panchu Band',
#   'Views': '8.8M views',
#   'Post-Time': '2 days ago'},
#  {'Channel': 'T-Series',
#   'Title': 'Guru Randhawa: Fake Love (Video) Man of The Moon | Sanjoy, Royal Maan, Amar Sandhu | Bhushan Kumar',
#   'Views': '7.8M views',
#   'Post-Time': '2 days ago'},
#  {'Channel': 'T-Series',
#   'Title': 'Vikram Vedha Trailer Screenings For Fans (10 Cities) | Hrithik Roshan, Radhika Apte | Bhushan Kumar',
#   'Views': '191K views',
#   'Post-Time': '3 days ago'},
#  {'Channel': 'T-Series',
#   'Title': 'Ek Number Dance Hits (Video Jukebox) | Dance Hit Songs 2022 | Naacho Naacho',
#   'Views': '96K views',
#   'Post-Time': '3 days ago'},
#  {'Channel': 'T-Series',
#   'Title': 'Vikram Vedha Trailer Launch Event | Hrithik Roshan, Radhika Apte | Fans Reaction | Bhushan Kumar',
#   'Views': '286K views',
#   'Post-Time': '4 days ago'},
#  {'Channel': 'T-Series',
#   'Title': 'Dhokha: Round D Corner (Trailer) | R. Madhavan, Khushalii, Darshan, Aparshakti | Kookie G, Bhushan K',
#   'Views': '15M views',
#   'Post-Time': '4 days ago'},
#  {'Channel': 'T-Series',
#   'Title': 'Sunidhi Chauhan: Chaap Tilak (Video) KARTOOT | Madalsa, Sahil | Anil Dutt, Anisadh | Anup Jalota',
#   'Views': '258K views',
#   'Post-Time': '5 days ago'},
#  {'Channel': 'T-Series',
#   'Title': 'Thank God (Official Trailer) Ajay Devgn, Sidharth Malhotra, Rakul | Indra Kumar | Bhushan Kumar',
#   'Views': '38M views',
#   'Post-Time': '5 days ago'},
#  {'Channel': 'T-Series',
#   'Title': 'Vikram Vedha Official Trailer | Hrithik Roshan, Saif Ali Khan, Pushkar & Gayatri |IN CINEMAS 30 SEPT',
#   'Views': '47M views',
#   'Post-Time': '6 days ago'},
#  {'Channel': 'T-Series',
#   'Title': 'Love Status ❤️ #ArijitSingh ❤️  Aashiqui ❤️ Chahun Mai Ya Na ❤️ #Shorts ❤️ #LoveStatus ❤️',
#   'Views': '130K views',
#   'Post-Time': '6 days ago'},
#  {'Channel': 'T-Series',
#   'Title': 'Kabir Singh Attitude Status Video 😡 #KabirSingh 😡 #Shahid 😎 #attitudestatus #shorts',
#   'Views': '494K views',
#   'Post-Time': '7 days ago'},
#  {'Channel': 'T-Series',
#   'Title': 'Woh 3 Din (Official Trailer) Sanjay Mishra | Chandan Sanyal,Rajesh Sharma |Raaj Aashoo,Pancham Singh',
#   'Views': '8.9M views',
#   'Post-Time': '7 days ago'},
#  {'Channel': 'T-Series',
#   'Title': '#JubinNautiyal 👨\u200d🎤 #Maafi 🙏🏻 💔 #LoveStatus ❤️ #shorts | Jubin Nautiyal Song Status',
#   'Views': '335K views',
#   'Post-Time': '9 days ago'},
#  {'Channel': 'T-Series',
#   'Title': 'Neha Kakkar, Rohanpreet: Baarish Mein Tum | Gauahar K, Zaid D | Showkidd, Harsh, Samay | Bhushan K',
#   'Views': '18M views',
#   'Post-Time': '9 days ago'},
#  {'Channel': 'T-Series',
#   'Title': 'Tujhe Bhula Diya (LoFi Mix) Kedrock & SD Style | Mohit Chauhan, Shekhar R, Shruti P | Bhushan Kumar',
#   'Views': '656K views',
#   'Post-Time': '10 days ago'},
#  {'Channel': 'T-Series',
#   'Title': 'Jubin Nautiyal Devotional Hits (Video Jukebox) | Kabir Dohe| Devotional Jukebox 2022 | Bhushan Kumar',
#   'Views': '166K views',
#   'Post-Time': '10 days ago'},
#  {'Channel': 'T-Series',
#   'Title': '#GanpatiStatus2022 🙏🏻 Hey Vighnaraya ❤️ #GanpatiBappaMorya 🐘  #Ganpati2022 🙏🏻  #shorts ❤️',
#   'Views': '34K views',
#   'Post-Time': '11 days ago'},
#  {'Channel': 'T-Series',
#   'Title': 'Aala re Aala Deva ❤️#GanpatiStatus2022 🙏🏻  #GanpatiBappaMorya 🐘  #Ganpati2022 🙏🏻  #shorts ❤️',
#   'Views': '32K views',
#   'Post-Time': '11 days ago'},
#  {'Channel': 'T-Series',
#   'Title': '#GanpatiStatus2022 🙏🏻 Ekdant Deva Shri ❤️ #GanpatiBappaMorya 🐘  #Ganpati2022 🙏🏻  #shorts ❤️',
#   'Views': '22K views',
#   'Post-Time': '11 days ago'},
#  {'Channel': 'T-Series',
#   'Title': '#Salmankhan ❤️ #GanpatiStatus2022 🙏🏻 Tera Hi Jalwa ❤️ #GanpatiBappaMorya 🐘  #Ganpati2022 🙏🏻  #shorts',
#   'Views': '49K views',
#   'Post-Time': '11 days ago'},
#  {'Channel': 'T-Series',
#   'Title': '#prabhudeva ❤️ #GanpatiStatus2022 🙏🏻 Deva Deva ❤️  #GanpatiBappaMorya 🐘  #Ganpati2022 🙏🏻  #shorts ❤️',
#   'Views': '46K views',
#   'Post-Time': '11 days ago'},
#  {'Channel': 'T-Series',
#   'Title': '#GanpatiStatus2022 🙏🏻 Bappa Boss ❤️ Boss Bappa ❤️ #GanpatiBappaMorya 🐘  #Ganpati2022 🙏🏻  #shorts ❤️',
#   'Views': '20K views',
#   'Post-Time': '11 days ago'},
#  {'Channel': 'T-Series',
#   'Title': 'Dil Remix: DJ Abhi India |  Ek Villain Returns | Arjun, Disha | Kaushik-Guddu | Raghav C | Bhushan K',
#   'Views': '399K views',
#   'Post-Time': '11 days ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': "JJ's Treehouse Song | CoComelon Nursery Rhymes & Kids Songs",
#   'Views': '2.2M views',
#   'Post-Time': '1 day ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'Yes Yes Vegetables On The Farm + More Nursery Rhymes & Kids Songs - CoComelon',
#   'Views': '6.7M views',
#   'Post-Time': '4 days ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'Train Song Dance | Dance Party | CoComelon Nursery Rhymes & Kids Songs',
#   'Views': '8.2M views',
#   'Post-Time': '8 days ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'I Spy Song + More Nursery Rhymes & Kids Songs - CoComelon',
#   'Views': '9.4M views',
#   'Post-Time': '11 days ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'Fire Truck Song - Trucks For Kids | CoComelon Nursery Rhymes & Kids Songs',
#   'Views': '9.8M views',
#   'Post-Time': '2 weeks ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'The Wheels on the Bus Dance | CoComelon Nursery Rhymes & Kids Songs - Dance Party',
#   'Views': '11M views',
#   'Post-Time': '2 weeks ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'Play Outside at the Beach Song | CoComelon Nursery Rhymes & Kids Songs',
#   'Views': '47M views',
#   'Post-Time': '3 weeks ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'Opposites Song + More Nursery Rhymes & Kids Songs - CoComelon',
#   'Views': '13M views',
#   'Post-Time': '3 weeks ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': "Let's Go Camping Song | Summer Family Fun | CoComelon Nursery Rhymes & Kids Songs",
#   'Views': '16M views',
#   'Post-Time': '4 weeks ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'Baa Baa Black Sheep (Pretend Play Edition) + More Nursery Rhymes & Kids Songs - CoComelon',
#   'Views': '13M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'Yes Yes Vegetables #2 CoComelon Nursery Rhymes & Kids Songs',
#   'Views': '16M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'Shopping Cart Song + More Nursery Rhymes & Kids Songs - CoComelon',
#   'Views': '33M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'Los Pollitos Dicen Dance | Dance Party | CoComelon Nursery Rhymes & Kids Songs',
#   'Views': '10M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'Birthday At The Farm Song + More Nursery Rhymes & Kids Songs - CoComelon',
#   'Views': '22M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'Finger Family Song + More Nursery Rhymes & Kids Songs - CoComelon',
#   'Views': '10M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'Baa Baa Black Sheep | CoComelon Nursery Rhymes & Kids Songs',
#   'Views': '15M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'Birthday Song + More Nursery Rhymes & Kids Songs - CoComelon',
#   'Views': '15M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'Big Brother Song + More Nursery Rhymes & Kids Songs - CoComelon',
#   'Views': '9.3M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': "JJ's Birthday At The Farm Song | CoComelon Nursery Rhymes & Kids Songs",
#   'Views': '11M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'Baa Baa Black Sheep Dance | Dance Party | + More Nursery Rhymes & Kids Songs - CoComelon',
#   'Views': '6.8M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': "Cody's Spy Song + More Nursery Rhymes & Kids Songs - CoComelon",
#   'Views': '9.2M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': "JJ's Birthday Surprise Song | CoComelon Nursery Rhymes & Kids Songs",
#   'Views': '28M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'Go Before You Go Song + More Nursery Rhymes & Kids Songs - CoComelon',
#   'Views': '13M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'Belly Button Dance | Dance Party | CoComelon Nursery Rhymes & Kids Songs',
#   'Views': '28M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'Twinkle Twinkle Little Star + More Nursery Rhymes & Kids Songs - CoComelon',
#   'Views': '26M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'Go Before You Go Song | CoComelon Nursery Rhymes & Kids Songs',
#   'Views': '11M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'London Bridge + More Nursery Rhymes & Kids Songs - CoComelon',
#   'Views': '24M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'Freeze Dance | Dance Party | CoComelon Nursery Rhymes & Kids Songs',
#   'Views': '33M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'Wheels On The Bus + More Nursery Rhymes & Kids Songs - CoComelon',
#   'Views': '38M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Cocomelon - Nursery Rhymes',
#   'Title': 'Twinkle Twinkle Little Star | CoComelon Nursery Rhymes & Kids Songs',
#   'Views': '33M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'SET India',
#   'Title': 'Kaun Banega Crorepati Season 14 - कौन बनेगा करोड़पति सीजन 14 - Ep 30 - Coming Up Next',
#   'Views': '10K views',
#   'Post-Time': '6 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'The Kapil Sharma Show | Kapil Karne Aaya Hai Sabki Help! | Best Moments',
#   'Views': '24K views',
#   'Post-Time': '7 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'The Kapil Sharma Show | Krushna Ko Pasand Aaya Audience Ka Involvement | Best Moments',
#   'Views': '47K views',
#   'Post-Time': '7 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'Udit जी ने किया Prity के साथ Perform | Super Star Singer | Pop Album',
#   'Views': '39K views',
#   'Post-Time': '7 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'Yashomati Maiyaa Ke Nandlala - यशोमती मैय्या के नंदलाला - Ep 72 - Coming Up Next',
#   'Views': '9.2K views',
#   'Post-Time': '7 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'Sawai के पहली Line गाते ही Neha ने बोला "वाह" | Indian Idol Season 12 | Ep - 2 | Full Episode',
#   'Views': '133K views',
#   'Post-Time': '7 hours ago'},
#  {'Channel': 'SET India',
#   'Title': '"Chaiyya Chaiyya" जैसे Song पर ऐसे Classical Act ने लगा दिए चार चाँद |India\'s Best Dancer| Album Mix',
#   'Views': '81K views',
#   'Post-Time': '8 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'Bade Achhe Lagte Hain 2 - Ep 274 - Coming Up Next - बड़े अच्छे लगते हैं 2',
#   'Views': '39K views',
#   'Post-Time': '8 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'क्या Nikhil मना पाएगा Pallavi को? | Appnapan - Badalate Rishton Ka Bandhan | Nikhil Pallavi Moments',
#   'Views': '19K views',
#   'Post-Time': '8 hours ago'},
#  {'Channel': 'SET India',
#   'Title': "Family's Crime | Crime Patrol 2.0 - Ep 100 | Full Episode | 22 July 2022",
#   'Views': '137K views',
#   'Post-Time': '8 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'Punyashlok Ahilya Bai - Ep 444 - Coming Up Next - पुण्यश्लोक अहिल्या बाई',
#   'Views': '44K views',
#   'Post-Time': '8 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'क्या CID से Criminals पहचान ने में हुई भूल? | सी आई डी | CID | Prime Time',
#   'Views': '29K views',
#   'Post-Time': '9 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'Danish की ज़ोरदार Performance से Zeenat Aman जी हुई खुश | Indian Idol | Evergreen Album',
#   'Views': '48K views',
#   'Post-Time': '9 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'Mere Sai - Ep 1221 - Coming Up Next - मेरे साईं',
#   'Views': '10K views',
#   'Post-Time': '9 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'Appnapan - Badalate Rishton Ka Bandhan - अपनापन बदलते रिश्तों का बंधन - Ep 67 - Coming Up Next',
#   'Views': '36K views',
#   'Post-Time': '9 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'Krishna And His Plans | Yashomati Maiyaa Ke Nandlala | Mon-Fri, 8:30 PM',
#   'Views': '12K views',
#   'Post-Time': '9 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'इस Performance को सुनकर Anil जी को याद आई कुछ Sweet Memories | Indian Idol Junior | Musical Hits',
#   'Views': '73K views',
#   'Post-Time': '10 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'क्यों लगा लिया Khanderao ने Ahilya को गले? | Punyashlok Ahilya Bai | Khanderao And Ahilya Moments',
#   'Views': '22K views',
#   'Post-Time': '10 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'Kapil को क्यों लगता है की Tahir करते हैं झोल? | The Kapil Sharma Show | Full Episode',
#   'Views': '26K views',
#   'Post-Time': '11 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'काल-कुंभ से कैसे बाहर निकलेगा हनुमान? | Sankatmochan Mahabali Hanuman-Ep 180 | Full Ep',
#   'Views': '8.8K views',
#   'Post-Time': '11 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'Himesh को याद आया Sridevi जी का एक किस्सा | Indian Idol | Himesh Approved',
#   'Views': '38K views',
#   'Post-Time': '11 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'Driving को लेकर Ram और Priya में हुई बहस | Bade Acche Lagte Hain 2 | Music Bytes',
#   'Views': '16K views',
#   'Post-Time': '11 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'कौन से "घोड़े" दौड़ा रहा है यह Vakeel? | The Kapil Sharma Show | Siddharth Sagar Comedy',
#   'Views': '200K views',
#   'Post-Time': '11 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'हनुमान ने फिर से दिखाई बहादुरी | Sankatmochan Mahabali Hanuman-Ep 179 | Full Ep',
#   'Views': '8.2K views',
#   'Post-Time': '12 hours ago'},
#  {'Channel': 'SET India',
#   'Title': '"Ye Kaali Kaali Aankhen" गाना सुनकर Vishal को आए Goosebumps | Indian Idol | Vishal Approved',
#   'Views': '34K views',
#   'Post-Time': '12 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'Ayushmann ने क्यों बेचे Fruits? | The Kapil Sharma Show | Celebrity Birthday Special',
#   'Views': '14K views',
#   'Post-Time': '12 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'Ram And Priya Have A Talk | Bade Achhe Lagte Hain - Ep 331 | Full Episode',
#   'Views': '46K views',
#   'Post-Time': '12 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'A House Full Of Dark Secrets | Crime Patrol 2.0 | New Episodes | Tonight At 11:00 PM',
#   'Views': '14K views',
#   'Post-Time': '13 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'शिक्षा पाने के लिए हनुमान जी को देनी पड़ेगी परीक्षा | Sankatmochan Mahabali Hanuman-Ep 178 | Full Ep',
#   'Views': '3.7K views',
#   'Post-Time': '13 hours ago'},
#  {'Channel': 'SET India',
#   'Title': 'Is Ayushmann Truly Faster Than Shaktimaan?|The Kapil Sharma Show|Celebrity Birthday Special',
#   'Views': '16K views',
#   'Post-Time': '13 hours ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'Why I didnt quit',
#   'Views': '2.1M views',
#   'Post-Time': '12 hours ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'Felix is scared of bugs.. (collab with @PewDiePie )',
#   'Views': '1.6M views',
#   'Post-Time': '10 days ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'I try EVERY Japanese Snack..(Collab with @PewDiePie )',
#   'Views': '2.7M views',
#   'Post-Time': '2 weeks ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'Japanese Karaoke, but I cant sing..',
#   'Views': '1.6M views',
#   'Post-Time': '2 weeks ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'Stream Fails (Top 1)',
#   'Views': '2.1M views',
#   'Post-Time': '3 weeks ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'We were warned not to go',
#   'Views': '1.8M views',
#   'Post-Time': '4 weeks ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'filming outside during my first typhoon for no good reason',
#   'Views': '1.8M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'you guys noticed something..',
#   'Views': '2.9M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'Proving that magic is REAL!',
#   'Views': '2.5M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'My Dog Cringes at TikToks..',
#   'Views': '3.1M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'A dream of mine came true today',
#   'Views': '3.3M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'Kid wants $1500 Allowance, to Buy Gucci Shoes....',
#   'Views': '3M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'No YouTuber dares to box me after seeing this',
#   'Views': '2.9M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'Old YouTube Was Kinda Crazy...',
#   'Views': '4.1M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'This was hard..',
#   'Views': '3.9M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'My 7 Billion $ Setup Tour',
#   'Views': '5M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'Reacting to the greatest cringe of all time..',
#   'Views': '3.3M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'We went to Italy...?',
#   'Views': '3.5M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'Something is seriously wrong with tiktoks (ylyl)',
#   'Views': '2.8M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'I accidentally got 2 cars..',
#   'Views': '4.1M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'Jaiden Smith Did it Again..',
#   'Views': '4.2M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'New Member to the Family!',
#   'Views': '5.9M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'Why Japan?',
#   'Views': '4.5M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'We Failed',
#   'Views': '6M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'I JUST MORBED',
#   'Views': '4.4M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'This show is PEAK Entertainment!',
#   'Views': '4.5M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'First time driving in Japan...',
#   'Views': '5.4M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'cant believe markiplier did this to me',
#   'Views': '4M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'whats next?',
#   'Views': '6.1M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'PewDiePie',
#   'Title': 'It finally happened!',
#   'Views': '8.1M views',
#   'Post-Time': '4 months ago'},
#  {'Channel': 'MrBeast',
#   'Title': 'I Hunted 100 People For $1,000,000',
#   'Views': '31M views',
#   'Post-Time': '11 days ago'},
#  {'Channel': 'MrBeast',
#   'Title': 'I Survived A Plane Crash',
#   'Views': '50M views',
#   'Post-Time': '3 weeks ago'},
#  {'Channel': 'MrBeast',
#   'Title': 'I Gave My 100,000,000th Subscriber An Island',
#   'Views': '68M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'MrBeast',
#   'Title': '100,000,000 Subscriber Special',
#   'Views': '20M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'MrBeast',
#   'Title': '100 Girls Vs 100 Boys For $500,000',
#   'Views': '76M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'MrBeast',
#   'Title': 'I Didn’t Eat Food For 30 Days',
#   'Views': '52M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'MrBeast',
#   'Title': "I Built Willy Wonka's Chocolate Factory!",
#   'Views': '103M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'MrBeast',
#   'Title': '$10,000 Every Day You Survive Prison',
#   'Views': '95M views',
#   'Post-Time': '5 months ago'},
#  {'Channel': 'MrBeast',
#   'Title': 'Would You Swim With Sharks For $100,000?',
#   'Views': '88M views',
#   'Post-Time': '5 months ago'},
#  {'Channel': 'MrBeast',
#   'Title': 'World’s Most Dangerous Escape Room!',
#   'Views': '130M views',
#   'Post-Time': '7 months ago'},
#  {'Channel': 'MrBeast',
#   'Title': 'Extreme $1,000,000 Hide And Seek',
#   'Views': '73M views',
#   'Post-Time': '8 months ago'},
#  {'Channel': 'MrBeast',
#   'Title': '$1,000,000 Influencer Tournament!',
#   'Views': '58M views',
#   'Post-Time': '8 months ago'},
#  {'Channel': 'MrBeast',
#   'Title': 'I Got Hunted By The Military',
#   'Views': '84M views',
#   'Post-Time': '9 months ago'},
#  {'Channel': 'MrBeast',
#   'Title': '$456,000 Squid Game In Real Life!',
#   'Views': '287M views',
#   'Post-Time': '9 months ago'},
#  {'Channel': 'MrBeast',
#   'Title': 'I Cleaned The World’s Dirtiest Beach #TeamSeas',
#   'Views': '69M views',
#   'Post-Time': '10 months ago'},
#  {'Channel': 'MrBeast',
#   'Title': 'Last To Take Hand Off Lamborghini, Keeps It',
#   'Views': '100M views',
#   'Post-Time': '10 months ago'},
#  {'Channel': 'MrBeast',
#   'Title': 'First To Rob Bank Wins $100,000',
#   'Views': '83M views',
#   'Post-Time': '11 months ago'},
#  {'Channel': 'MrBeast',
#   'Title': 'Extreme $500,000 Game Of Tag!',
#   'Views': '81M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'MrBeast',
#   'Title': 'Last To Leave Circle Wins $500,000',
#   'Views': '185M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'MrBeast',
#   'Title': 'I Got Hunted By The FBI',
#   'Views': '104M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'MrBeast',
#   'Title': 'If You Can Carry $1,000,000 You Keep It!',
#   'Views': '87M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'MrBeast',
#   'Title': 'Would YOU Quit School For $100,000?',
#   'Views': '75M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'MrBeast',
#   'Title': 'I Survived 50 Hours In A Maximum Security Prison',
#   'Views': '119M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'MrBeast',
#   'Title': 'Hit The Target, Win $300,000',
#   'Views': '108M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'MrBeast',
#   'Title': 'Anything You Can Fit In The Triangle I’ll Pay For',
#   'Views': '92M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'MrBeast',
#   'Title': 'I Got Hunted By A Real Bounty Hunter',
#   'Views': '107M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'MrBeast',
#   'Title': 'Extreme $100,000 Game of Tag!',
#   'Views': '110M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'MrBeast',
#   'Title': 'Would You Sit In Snakes For $10,000?',
#   'Views': '159M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'MrBeast',
#   'Title': "I Bought The World's Largest Mystery Box! ($500,000)",
#   'Views': '138M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'MrBeast',
#   'Title': 'I Spent 50 Hours Buried Alive',
#   'Views': '194M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and Roma explore the Professions of the Future',
#   'Views': '2.7M views',
#   'Post-Time': '3 days ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and Roma Entertainment for kids at the hotel',
#   'Views': '4.6M views',
#   'Post-Time': '8 days ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana Roma Oliver Birthday Video Collection',
#   'Views': '6.6M views',
#   'Post-Time': '2 weeks ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and Roma Family trip to the sea',
#   'Views': '6.7M views',
#   'Post-Time': '2 weeks ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and Roma Escape Room and more funny challenges',
#   'Views': '3.6M views',
#   'Post-Time': '3 weeks ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and Roma Back to School stories',
#   'Views': '10M views',
#   'Post-Time': '3 weeks ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana Roma and Oliver Have a Fun Day at the Kids Club',
#   'Views': '14M views',
#   'Post-Time': '3 weeks ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and Roma Family summer vacation',
#   'Views': '12M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and Roma play outdoors / best parks for kids',
#   'Views': '12M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and Roma show School rules / New Back to School story',
#   'Views': '12M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and Roma visited Disneyland!',
#   'Views': '9.6M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and Oliver - favorite stories with little brother',
#   'Views': '30M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and Roma Kids Activities during the summer vacation',
#   'Views': '22M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and Roma Family Fun Time at the Amusement Park',
#   'Views': '9.5M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and Roma help Oliver and other New stories',
#   'Views': '34M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana Roma and Oliver play Different Jobs and Professions',
#   'Views': '20M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and Roma in the Escape Room Challenge',
#   'Views': '186M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and Roma Follow the Rules / video compilation',
#   'Views': '22M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and Roma 24 Hours on the Boat Challenge',
#   'Views': '21M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and Roma at School - A Story about the Value of Friendship',
#   'Views': '89M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and Dad in The Magic Story of Studying at Home',
#   'Views': '37M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and Roma Adventure in the Cinema and other Funniest videos for kids',
#   'Views': '107M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana teaches baby Oliver | Developmental Games for a 1+ Year Old',
#   'Views': '13M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and Roma have fun on the First Day of Summer following safety tips',
#   'Views': '48M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and useful stories about good behavior from her life',
#   'Views': '179M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and Roma play Cinema challenge',
#   'Views': '75M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana teaches Roma how to keep Eyesight',
#   'Views': '8.8M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and Roma came up with How to Entertain baby Oliver | Fun Toddler Activities',
#   'Views': '36M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and Roma Travel - Video compilation about fun family trips',
#   'Views': '54M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'Kids Diana Show',
#   'Title': 'Diana and Mom visit the dentist / Brush your teeth story',
#   'Views': '34M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya and stories about elementary school and her classmates',
#   'Views': '3M views',
#   'Post-Time': '4 days ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya reads books and uses the Internet to get new information',
#   'Views': '4.6M views',
#   'Post-Time': '8 days ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya is learning why children need to go to school',
#   'Views': '3.8M views',
#   'Post-Time': '11 days ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya shares the secrets of how to become a successful blogger',
#   'Views': '4.4M views',
#   'Post-Time': '2 weeks ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya learns how important it is for children to wear braces',
#   'Views': '6.5M views',
#   'Post-Time': '2 weeks ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya does good deeds like a superhero',
#   'Views': '6.2M views',
#   'Post-Time': '3 weeks ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya and the most interesting moments from the summer vacation',
#   'Views': '5.8M views',
#   'Post-Time': '3 weeks ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya and her back to school in the third grade',
#   'Views': '3.7M views',
#   'Post-Time': '4 weeks ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya and a family trip to London with dad',
#   'Views': '9.5M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya shows how to entertain each other with her dad',
#   'Views': '14M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya learns to say the magic word Please and receives a gift',
#   'Views': '3.4M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya kids stories and summer rules',
#   'Views': '39M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya and dad Family fun time in the Land of Legends park',
#   'Views': '8.2M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya and kids outdoor activities in Turkey',
#   'Views': '34M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya and her friends are trying to find their favorite hobbies',
#   'Views': '25M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya and Dad travel around Italy on summer vacation',
#   'Views': '5.9M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya and stories about how important it is to take care of your health',
#   'Views': '22M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya and summer safety rules for children',
#   'Views': '11M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya is learning how to get new information during the summer holidays',
#   'Views': '11M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya at School and other Stories about the Importance of Studying',
#   'Views': '50M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya and Dad learn how to cook pasta in Italy',
#   'Views': '12M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya shows 5 sights worth visiting during a family trip to Switzerland',
#   'Views': '9.3M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya shows that washing hands is not boring at all',
#   'Views': '52M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya and dad travel in Alsace and in the gingerbread museum',
#   'Views': '6.3M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya and the rules of conduct in the Hotel',
#   'Views': '16M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya and the most important safety rules for children',
#   'Views': '34M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya shows the safety rules in the pool',
#   'Views': '65M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya shows the harm of sugar on health',
#   'Views': '13M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya at School - Video compilation about school, friendship and knowledge',
#   'Views': '44M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'Like Nastya',
#   'Title': 'Nastya and the story about school bullying',
#   'Views': '131M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'Ijazzat Hai - Lyrical | Shivin N & Jasmin B | Raj Barman, Sachin Gupta, Kumaar | Zee Music Originals',
#   'Views': '137K views',
#   'Post-Time': '9 hours ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'Middle-Class Love | Dialogue Promo 3 | Prit K, Kavya T, Eisha S | Ratnaa S | Anubhav S | 16th Sept',
#   'Views': '29K views',
#   'Post-Time': '9 hours ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'Dhaage - Full Album | Nikhil Chaudhary, Swati Negi |  Sadhu S.Tiwari | Rohit Sharma',
#   'Views': '26K views',
#   'Post-Time': '12 hours ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'Manmarzi - Dhaage | Ankurr Maan | Nikhil Chaudhary, Swati Negi | Palak Muchhal, Raj Barman | Sadhu S',
#   'Views': '66K views',
#   'Post-Time': '13 hours ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': '#TuDisDa #Cuttputlli #AkshayKumar #RakulPreetSingh #DrZeus #HamidAliNaqeebi #shorts',
#   'Views': '79K views',
#   'Post-Time': '17 hours ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': '#Banarasiya #SarojKaRishta #SonikaSharma #DheerajPandey#VickkyAgarwal #SanahKapur #RandeepRai#shorts',
#   'Views': '42K views',
#   'Post-Time': '18 hours ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'Ishq Ishq Karke - Mohsin Khan & Priyanka Khera | Stebin Ben | Kausar Jamot | Zee Music Originals',
#   'Views': '2M views',
#   'Post-Time': '18 hours ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'Aashiq Hoon - Lyrical | Mohsin & Aneri | Raj Barman, Raees & Zain-Sam, Vikki N | Zee Music Originals',
#   'Views': '298K views',
#   'Post-Time': '1 day ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'Dil Mein Thee - Aa Bhi Ja O Piya | Dev Sharma, Smriti Kashyap | Sonu Nigam | Ashutosh Singh',
#   'Views': '35K views',
#   'Post-Time': '1 day ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'Raksha Bandhan - Title Track | Akshay Kumar & Bhumi Pednekar | Shreya Ghoshal, Himesh R, Irshad K',
#   'Views': '150K views',
#   'Post-Time': '1 day ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'Nadaniyaan #MellowD #BabaTheDoorbeen #Nikkesha #DJRuchir #ZeeMusicOriginals #shorts',
#   'Views': '58K views',
#   'Post-Time': '1 day ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'Banarasiya - Saroj Ka Rishta | Sonika Sharma, Dheeraj P | Vickky A | Sanah, Randeep, Kumud, Gaurav',
#   'Views': '62K views',
#   'Post-Time': '1 day ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'बिन फेरे हम तेरे Bin Phere Hum Tere - Full Movie | Rajendra Kumar, Asha Parekh, Vinod Mehra',
#   'Views': '160K views',
#   'Post-Time': '1 day ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': '#MadBanke #BabliBouncer #TamannaahBhatia #AseesKaur #Romy #TanishkBagchi #ShabbirAhmed #shorts',
#   'Views': '95K views',
#   'Post-Time': '1 day ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'Tu Dis Da - Cuttputlli | Akshay Kumar & Rakul Preet | Dr Zeus & Hamid Ali Naqeebi',
#   'Views': '211K views',
#   'Post-Time': '1 day ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': '#JaikalMahakal #Goodbye #AmitabhBachchan #RashmikaMandanna #AmitTrivedi #lordshiva #shorts',
#   'Views': '54K views',
#   'Post-Time': '1 day ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': '#OmJaiJagdish #AmitTrivedi #AmitabhBhattacharya #devotionalsong #lordvishnu #shorts',
#   'Views': '40K views',
#   'Post-Time': '1 day ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'Jaikal Mahakal - Goodbye | Amitabh Bachchan & Rashmika Mandanna | Amit Trivedi | Swanand Kirkire',
#   'Views': '3.8M views',
#   'Post-Time': '2 days ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'जय हिंद Jai Hind - Full Movie | Rishi Kapoor, Kunal Goswami, Shilpa Shirodkar, Manisha Koirala',
#   'Views': '416K views',
#   'Post-Time': '2 days ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'Mad Banke - Babli Bouncer | Tamannaah Bhatia | Asees Kaur, Romy, Tanishk Bagchi, Shabbir Ahmed',
#   'Views': '3.9M views',
#   'Post-Time': '2 days ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'Om Jai Jagdish - Amit Trivedi | Amitabh Bhattacharya | Zee Music Originals',
#   'Views': '86K views',
#   'Post-Time': '2 days ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'Jogan Tere Ishq Di - Official Music Video | Tanya Sood | Harry Anand | Karan Oberoi',
#   'Views': '2M views',
#   'Post-Time': '2 days ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'Do Ghante - Ishq Pashmina | Kainaat Arora, Bhavin Bhanushali, Brijendra K | Sakshi Holkar',
#   'Views': '87K views',
#   'Post-Time': '2 days ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'Hypnotize - Middle-Class Love | Prit Kamani, Kavya Thapar | Himesh R, Dev N, Akasa, Aasa | 16th Sept',
#   'Views': '230K views',
#   'Post-Time': '4 days ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'Subway - Official Trailer | Ravi Kishan, Vishal Vishesh, Naazuk, Devendra Chaudhry',
#   'Views': '47K views',
#   'Post-Time': '5 days ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'Aa Bhi Ja O Piya - Title Track | Dev Sharma, Smriti K| Deepali Sahay, Hitesh Kumar |Rajesh Harivansh',
#   'Views': '25K views',
#   'Post-Time': '5 days ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'Jahan Bhi Jao Aai Sanam Bas Tu Hi Tu - Prem Geet 3 | Rahat Fateh Ali Khan | Pradeep Khadka, Kristina',
#   'Views': '2M views',
#   'Post-Time': '5 days ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'जंगल में मंगल Jangal Mein Mangal - Full movie | Kiran Kumar, Reena Roy, Pran, Balraj Sahni',
#   'Views': '120K views',
#   'Post-Time': '6 days ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'मेरे लाल Mere Lal - Full Movie | Dev Kumar, Indrani Mukherjee, Mala Sinha | 1966 Hindi Movie',
#   'Views': '28K views',
#   'Post-Time': '6 days ago'},
#  {'Channel': 'Zee Music Company',
#   'Title': 'अर्पण Arpan - Full Movie | Nimmi, Sheila Ramani, Chetan Anand & Sitara | Jaidev Verma',
#   'Views': '17K views',
#   'Post-Time': '6 days ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Vlad and Niki have fun with Hot Wheels Skate fingerboards and playsets',
#   'Views': '2.3M views',
#   'Post-Time': '18 hours ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Chris and the most important safety rules for children',
#   'Views': '5.4M views',
#   'Post-Time': '3 days ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Vlad and Niki Four Colors Playhouse Challenge and more funny stories for kids',
#   'Views': '21M views',
#   'Post-Time': '8 days ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Niki plays with Mixies Toy and help his friends',
#   'Views': '1.4M views',
#   'Post-Time': '11 days ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Vlad and Niki play with Heroes of Goo Jit Zu Toys',
#   'Views': '2.2M views',
#   'Post-Time': '2 weeks ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Vlad and Niki in the Best Challenge and Stories for kids',
#   'Views': '2.2M views',
#   'Post-Time': '2 weeks ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Vlad and Niki funny and useful stories for kids',
#   'Views': '11M views',
#   'Post-Time': '3 weeks ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Niki and Chris - favorite stories with little brother',
#   'Views': '20M views',
#   'Post-Time': '3 weeks ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Vlad and Niki Family trip to Bahamas',
#   'Views': '7.4M views',
#   'Post-Time': '4 weeks ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': "Chris and mom explore children's museum and learning center for kids",
#   'Views': '6.3M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Vlad and Niki Octonauts Toy Animals Rescue Mission',
#   'Views': '9.9M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Chris and Mom in Farm Stories for Kids',
#   'Views': '13M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Vlad and Niki help their friends - best stories for children',
#   'Views': '22M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Vlad and Niki Four Colors Playhouse Challenge',
#   'Views': '36M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Vlad and Niki and stories about how important is it to be kind and honest',
#   'Views': '6.9M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Vlad and Niki in the Escape Room Challenge',
#   'Views': '6M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Solve the Mystery Challenge with Chris and Mom',
#   'Views': '9.9M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Educational stories for kids from Vlad and Niki',
#   'Views': '43M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Vlad and Mom exchanged cat and dog pets - new episode for children',
#   'Views': '3.7M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': '1000 Mystery Buttons and more funny challenges with Vlad and Niki',
#   'Views': '63M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Vlad and Niki explore Summer Activities for children',
#   'Views': '29M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Chris becomes a superheroes and helps his friends',
#   'Views': '4.8M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Vlad and Niki 24 Hours Overnight in VAN house Challenge',
#   'Views': '4.7M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Chris learns to cook food for drive thru cafe',
#   'Views': '18M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Chris and mom learn how to harvest fruits and vegetables and feeding the animals at the farm',
#   'Views': '35M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'All Day Yes Challenge with Vlad and Niki',
#   'Views': '2.9M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Niki celebrates his 7th birthday with friends',
#   'Views': '35M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Chris and Mom try to find healthy ice cream in supermarket',
#   'Views': '39M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Niki becomes a pilot and saves his friends - best stories for kids',
#   'Views': '17M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'Vlad and Niki',
#   'Title': 'Niki learns to sleep alone',
#   'Views': '14M views',
#   'Post-Time': '3 months ago'},
#  {'Channel': 'Blackpink',
#   'Title': 'BLACKPINK - ‘Shut Down’ M/V TEASER',
#   'Views': '13M views',
#   'Post-Time': '1 day ago'},
#  {'Channel': 'Blackpink',
#   'Title': 'BLACKPINK - ‘Pink Venom’ [Light Up The Pink] Campaign 2022 Compilation',
#   'Views': '6.9M views',
#   'Post-Time': '2 weeks ago'},
#  {'Channel': 'Blackpink',
#   'Title': 'BLACKPINK - ‘Pink Venom’ SPECIAL STAGE',
#   'Views': '25M views',
#   'Post-Time': '2 weeks ago'},
#  {'Channel': 'Blackpink',
#   'Title': 'BLACKPINK - ‘Pink Venom’ Visualizer',
#   'Views': '7.9M views',
#   'Post-Time': '2 weeks ago'},
#  {'Channel': 'Blackpink',
#   'Title': 'BLACKPINK WORLD TOUR [BORN PINK] SEOUL MESSAGE VIDEO',
#   'Views': '2.6M views',
#   'Post-Time': '2 weeks ago'},
#  {'Channel': 'Blackpink',
#   'Title': 'BLACKPINK - ‘Pink Venom’ M/V REACTION',
#   'Views': '10M views',
#   'Post-Time': '2 weeks ago'},
#  {'Channel': 'Blackpink',
#   'Title': 'BLACKPINK - ‘Pink Venom’ DANCE PRACTICE VIDEO',
#   'Views': '65M views',
#   'Post-Time': '3 weeks ago'},
#  {'Channel': 'Blackpink',
#   'Title': 'BLACKPINK x YouTube Shorts | #PinkVenomChallenge',
#   'Views': '3.2M views',
#   'Post-Time': '3 weeks ago'},
#  {'Channel': 'Blackpink',
#   'Title': "Create a Short to 'Pink Venom' & show us your moves with #PinkVenomChallenge only on YouTube Shorts",
#   'Views': '75M views',
#   'Post-Time': '3 weeks ago'},
#  {'Channel': 'Blackpink',
#   'Title': 'Show us what you’ve got. Join the #PinkVenomChallenge & dance along. Only on YouTube Shorts.',
#   'Views': '61M views',
#   'Post-Time': '3 weeks ago'},
#  {'Channel': 'Blackpink',
#   'Title': 'Bring your best dance moves and join the #PinkVenomChallenge with us. Only on YouTube Shorts.',
#   'Views': '96M views',
#   'Post-Time': '3 weeks ago'},
#  {'Channel': 'Blackpink',
#   'Title': 'Show us that you are BORN PINK and join us in the #PinkVenomChallenge Only on YouTube Shorts.',
#   'Views': '94M views',
#   'Post-Time': '3 weeks ago'},
#  {'Channel': 'Blackpink',
#   'Title': '“Get em, get em, get em” with us and join the #PinkVenomChallenge Only on YouTube Shorts.',
#   'Views': '106M views',
#   'Post-Time': '3 weeks ago'},
#  {'Channel': 'Blackpink',
#   'Title': "Create a Short to 'Pink Venom' & show us your moves with #PinkVenomChallenge only on YouTube Shorts",
#   'Views': '129M views',
#   'Post-Time': '3 weeks ago'},
#  {'Channel': 'Blackpink',
#   'Title': 'BLACKPINK - ‘Pink Venom’ M/V MAKING FILM',
#   'Views': '17M views',
#   'Post-Time': '3 weeks ago'},
#  {'Channel': 'Blackpink',
#   'Title': 'BLACKPINK - ‘Pink Venom’ M/V',
#   'Views': '296M views',
#   'Post-Time': '3 weeks ago'},
#  {'Channel': 'Blackpink',
#   'Title': 'BLACKPINK #PinkVenomChallenge Coming soon! #LISA',
#   'Views': '5.1M views',
#   'Post-Time': '4 weeks ago'},
#  {'Channel': 'Blackpink',
#   'Title': 'BLACKPINK #PinkVenomChallenge Coming soon! #ROSÉ',
#   'Views': '2.6M views',
#   'Post-Time': '4 weeks ago'},
#  {'Channel': 'Blackpink',
#   'Title': 'BLACKPINK #PinkVenomChallenge Coming soon! #JENNIE',
#   'Views': '2.3M views',
#   'Post-Time': '4 weeks ago'},
#  {'Channel': 'Blackpink',
#   'Title': 'BLACKPINK #PinkVenomChallenge Coming soon! #JISOO',
#   'Views': '2.6M views',
#   'Post-Time': '4 weeks ago'},
#  {'Channel': 'Blackpink',
#   'Title': 'BLACKPINK - ‘Pink Venom’ M/V TEASER',
#   'Views': '30M views',
#   'Post-Time': '4 weeks ago'},
#  {'Channel': 'Blackpink',
#   'Title': '#PinkVenomChallenge Coming Soon Only on YouTube Shorts',
#   'Views': '3.8M views',
#   'Post-Time': '4 weeks ago'},
#  {'Channel': 'Blackpink',
#   'Title': 'BLACKPINK - ‘Pink Venom’ Concept Teaser',
#   'Views': '12M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Blackpink',
#   'Title': 'BLACKPINK - ‘Pink Venom’ JISOO Concept Teaser #2',
#   'Views': '9.3M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Blackpink',
#   'Title': 'BLACKPINK - ‘Pink Venom’ JENNIE Concept Teaser #2',
#   'Views': '7M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Blackpink',
#   'Title': 'BLACKPINK - ‘Pink Venom’ ROSÉ Concept Teaser #2',
#   'Views': '8.7M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': 'Blackpink',
#   'Title': 'BLACKPINK - ‘Pink Venom’ LISA Concept Teaser #2',
#   'Views': '10M views',
# ...
#   'Views': '3 weeks ago',
#   'Post-Time': '320K views'},
#  {'Channel': 'El Reino Infantil',
#   'Title': 'Hickory Dickory Dock - CLEO Y CUQUÍN 👨🏻\u200d🦲👧🏻 CANCIONES 🎵 DIBUJOS ANIMADOS PARA NIÑOS',
#   'Views': '3 weeks ago',
#   'Post-Time': '238K views'},
#  {'Channel': 'El Reino Infantil',
#   'Title': '🐊 DANTE ¿Dónde Estás? 🐊 CANCIONES DEL ZOO 🐵 MIX 🎵 ESTRENO 🌈 DIBUJOS ANIMADOS PARA NIÑOS',
#   'Views': '3 weeks ago',
#   'Post-Time': '3.7M views'},
#  {'Channel': 'El Reino Infantil',
#   'Title': 'Las Hormiguitas Van Marchando 🐜Canciones Infantiles | El Reino Infantil',
#   'Views': '3 weeks ago',
#   'Post-Time': '177K views'},
#  {'Channel': 'El Reino Infantil',
#   'Title': '🎤 VAMOS A JUGAR y CANTAR 💃🏻 #2 CANCIONES INFANTILES 👶🏼 MIX 🌈 DIBUJOS ANIMADOS PARA NIÑOS',
#   'Views': '4 weeks ago',
#   'Post-Time': '265K views'},
#  {'Channel': 'El Reino Infantil',
#   'Title': 'Tengo una Hormiguita Y más CANCIONES INFANTILES 🎵 NIKA Y MATSU ⭐️ MIX 🌈 PARA NIÑOS',
#   'Views': '4 weeks ago',
#   'Post-Time': '1.7M views'},
#  {'Channel': 'El Reino Infantil',
#   'Title': 'EL AUTO BOCHINCHERO 🚙 LA GRANJA DE ZENÓN A RODAR 🚗 MIX 🎵 ESTRENO 🌈 DIBUJOS ANIMADOS PARA NIÑOS',
#   'Views': '1 month ago',
#   'Post-Time': '245K views'},
#  {'Channel': 'El Reino Infantil',
#   'Title': 'Ding Dong Suena la Campana🔔 SHARK ACADEMY 🦈 CANCIONES 🎵 DIBUJOS ANIMADOS PARA NIÑOS',
#   'Views': '1 month ago',
#   'Post-Time': '190K views'},
#  {'Channel': 'El Reino Infantil',
#   'Title': '😀 JUGUEMOS con los DINOSAURIOS más DIVERTIDOS 🦖GIGANTOSAURUS 🦖 MIX 🌈 DIBUJOS ANIMADOS PARA NIÑOS',
#   'Views': '1 month ago',
#   'Post-Time': '224K views'},
#  {'Channel': 'El Reino Infantil',
#   'Title': 'Picnic de Cumpleaños de Vera 🌈 VERA y el REINO ARCOÍRIS 🌈 EPISODIOS 🌞 PARA NIÑOS',
#   'Views': '1 month ago',
#   'Post-Time': '200K views'},
#  {'Channel': 'El Reino Infantil',
#   'Title': '🎶Vamos a Cantar con LEA Y POP 👩🏻\u200d🦰🧑🏻 MIX 🌈 DIBUJOS ANIMADOS PARA NIÑOS | El Reino Infantil',
#   'Views': '1 month ago',
#   'Post-Time': '8.4M views'},
#  {'Channel': 'El Reino Infantil',
#   'Title': 'La GRANJA de ZENÓN - Las 35 MEJORES CANCIONES de la GRANJA 👨🏻\u200d🌾 MIX 🌈 PARA NIÑOS',
#   'Views': '1 month ago',
#   'Post-Time': '3.4M views'},
#  {'Channel': 'El Reino Infantil',
#   'Title': 'Que LEVANTE la MANO ✋ PLIM PLIM 🤡 CANCIONES INFANTILES 🎵 DIBUJOS ANIMADOS PARA NIÑOS',
#   'Views': '1 month ago',
#   'Post-Time': '1.6M views'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande, Kid Cudi - Just Look Up (From Don’t Look Up) (Live on The Voice)',
#   'Views': '6M views',
#   'Post-Time': '8 months ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': "Ariana Grande & Kid Cudi - Just Look Up (Full Performance from ‘Don't Look Up’)",
#   'Views': '10M views',
#   'Post-Time': '9 months ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': "Ariana Grande & Kid Cudi - Just Look Up (From 'Don’t Look Up') (Official Lyric Video)",
#   'Views': '8.7M views',
#   'Post-Time': '9 months ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande - Positions Album (Official Live Performances) | Vevo',
#   'Views': '21M views',
#   'Post-Time': '10 months ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Fortnite Presents: Rift Tour Featuring Ariana Grande',
#   'Views': '7.5M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande - positions (Official Live Performance) | Vevo',
#   'Views': '23M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande - off the table ft. The Weeknd (Official Live Performance) | Vevo',
#   'Views': '14M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande - 34+35 (Official Live Performance) | Vevo',
#   'Views': '16M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande - my hair (Official Live Performance) | Vevo',
#   'Views': '14M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande - safety net ft. Ty Dolla $ign (Official Live Performance) | Vevo',
#   'Views': '17M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande - pov (Official Live Performance) | Vevo',
#   'Views': '32M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande - pov (official lyric video)',
#   'Views': '14M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'studio footage: vocal arranging the “positions” bridge - ariana grande',
#   'Views': '8.2M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'studio footage: "positions" outro - ariana grande',
#   'Views': '2.3M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande - main thing (official audio)',
#   'Views': '6.3M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande - worst behavior (official audio)',
#   'Views': '6.9M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande - test drive (official audio)',
#   'Views': '8.7M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande - someone like u (interlude) (official audio)',
#   'Views': '2.5M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande - 34+35 Remix (Countdown to Premiere)',
#   'Views': '2.2M views',
#   'Post-Time': 'Streamed 1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande - 34+35 (Remix) ft. Doja Cat, Megan Thee Stallion',
#   'Views': '95M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande - 34+35 (Remix / Lyric Video) ft. Doja Cat, Megan Thee Stallion',
#   'Views': '28M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande - excuse me, i love you (exclusive trailer)',
#   'Views': '9M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande - 34+35 (official video)',
#   'Views': '274M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande - R.E.M. Fragrance Commercial (Official Video)',
#   'Views': '3.9M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande - six thirty (audio)',
#   'Views': '12M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande - pov (audio)',
#   'Views': '95M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande, The Weeknd - off the table (audio)',
#   'Views': '22M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande, Doja Cat - motive (audio)',
#   'Views': '48M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande - safety net (audio) ft. Ty Dolla $ign',
#   'Views': '23M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': 'Ariana Grande',
#   'Title': 'Ariana Grande - just like magic (audio)',
#   'Views': '18M views',
#   'Post-Time': '1 year ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'Splish, Splash! Bubble, Bubble - LooLoo Kids Nursery Rhymes and Kids Songs',
#   'Views': '254K views',
#   'Post-Time': '1 day ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'Dance with A Ram Sam Sam and more Nursery Rhymes and Children`s Songs - LooLoo Kids',
#   'Views': '238K views',
#   'Post-Time': '4 days ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'Hello Song - Back To School - LooLoo Kids Nursery Rhymes & Kids Songs',
#   'Views': '1.8M views',
#   'Post-Time': '8 days ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'Johny Johny Yes Papa - Funny KIDS SONGS - LooLoo Kids Nursery Rhymes',
#   'Views': '978K views',
#   'Post-Time': '11 days ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': '𝑵𝑬𝑾 Ten in The Bed - LooLoo Kids Nursery Rhymes & Kids Songs',
#   'Views': '2.3M views',
#   'Post-Time': '2 weeks ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'Happy and Sad and more Sing Along Kids Songs - LooLoo Kids Nursery Rhymes',
#   'Views': '757K views',
#   'Post-Time': '2 weeks ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'Who Took The Cookies - LooLoo Kids Nursery Rhymes & Kids Songs',
#   'Views': '1.8M views',
#   'Post-Time': '3 weeks ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'Sleeping Bunnies and more Toddlers Songs - LooLoo Kids Nursery Rhymes',
#   'Views': '1.3M views',
#   'Post-Time': '3 weeks ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': '𝑵𝑬𝑾 🚌 Wheels On The Bus - LooLoo Kids Nursery Rhymes and Children`s Songs',
#   'Views': '2.7M views',
#   'Post-Time': '4 weeks ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'ABC Song | A is for Apple and more Learning Kids Songs with LooLoo Kids',
#   'Views': '1.4M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'My Little Neighbor - LooLoo Kids Nursery Rhymes and Children`s Songs',
#   'Views': '2M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'Learning Animals with Johny and Friends - LooLoo Kids Nursery Rhymes',
#   'Views': '922K views',
#   'Post-Time': '1 month ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'My Family - LooLoo Kids Nursery Rhymes and Children`s Songs',
#   'Views': '3.8M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'The Little Sailor Dance and More + More Nursery Rhymes & Kids Songs LooLoo Kids',
#   'Views': '676K views',
#   'Post-Time': '1 month ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'Vehicles Song - LooLoo Kids Nursery Rhymes and Children`s Songs',
#   'Views': '4.7M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'Dance with Johny and Friends - Fun Kids Songs Compilation - LooLoo Kids',
#   'Views': '3.3M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'Seven Continents - Learning Songs for Kids with LooLoo Kids Nursery Rhyme',
#   'Views': '11M views',
#   'Post-Time': '1 month ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'The Little Boat and More Funny Kids Songs - LooLoo Kids Nursery Rhymes',
#   'Views': '728K views',
#   'Post-Time': '1 month ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'Kids Songs Collection - Sing Along with LooLoo Kids Nursery Rhymes & Kids Songs',
#   'Views': '4.3M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'Johny and Mother Henny Penny and more LooLoo Kids Nursery Rhymes and Children`s Songs',
#   'Views': '1.1M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': '𝑵𝑬𝑾  Pussy Cat - Kindergarten Playtime - LooLoo Kids Nursery Rhymes & Kids Songs',
#   'Views': '2.5M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'A Flower In My Garden and more Kindergarten Kids Songs - LooLoo Kids Nursery Rhymes',
#   'Views': '1.9M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': '𝑵𝑬𝑾 Finger Family - Sing Along with LooLoo Kids Nursery Rhymes & Kids Songs',
#   'Views': '2.9M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'Happy Mom Stress Relief | Relaxing Music Video | Nature Relaxation',
#   'Views': '288K views',
#   'Post-Time': '2 months ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'Learn Musical Instruments and more Kids Songs and Nursery Rhymes - LooLoo Kids',
#   'Views': '1.5M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'Happy Mom | Zen Relaxing Music Video | Stress Relief',
#   'Views': '245K views',
#   'Post-Time': '2 months ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'Twinkle Twinkle Little Star + Wheels on the Bus and more Kids Songs and Nursery Rhymes - LooLoo Kids',
#   'Views': '1M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'Rolling Rolling + Wind the Bobbin - LooLoo Kids - Funny Kids Songs',
#   'Views': '2.3M views',
#   'Post-Time': '2 months ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'My Donkey Has a Headache and more Nursery Rhymes & Kids Songs - LooLoo Kids',
#   'Views': '729K views',
#   'Post-Time': '2 months ago'},
#  {'Channel': "LooLoo Kids - Nursery Rhymes and Children's Songs",
#   'Title': 'The Tinny Little Boat - LooLoo Kids Nursery Rhymes & Kids Songs #shorts',
#   'Views': '403K views',
#   'Post-Time': '2 months ago'},
#  {'Channel': 'YRF',
#   'Title': 'he cracked the code #ayushmannkhurrana #parineetichopra #meripyaaribindu #happybirthday #yrfshorts',
#   'Views': '18K views',
#   'Post-Time': '11 hours ago'},
#  {'Channel': 'YRF',
#   'Title': "can't miss her dance moves | छोड़ के सारे शर्म और लाज | #ghungroo #hrithikroshan #vaanikapoor #shorts",
#   'Views': '45K views',
#   'Post-Time': '1 day ago'},
#  {'Channel': 'YRF',
#   'Title': 'flirting game on point💯 #fanaa #aamirkhan #kajol #scene #dialogue #romantic #comedy #love #shyari',
#   'Views': '160K views',
#   'Post-Time': '2 days ago'},
#  {'Channel': 'YRF',
#   'Title': 'clever ya cheater? #ranveersingh #anushkasharma #bandbaajabaaraat #yrfshorts #yrf #scene #dialogue',
#   'Views': '141K views',
#   'Post-Time': '3 days ago'},
#  {'Channel': 'YRF',
#   'Title': 'this pairing makes this song 💯 #tujahaan #saifalikhan #preityzinta #sadsong #yrfshorts',
#   'Views': '89K views',
#   'Post-Time': '4 days ago'},
#  {'Channel': 'YRF',
#   'Title': 'don’t need anything else #tujhmeinrabdikhtahai #rabnebanadijodi #shahrukhkhan #anushkasharma #shorts',
#   'Views': '114K views',
#   'Post-Time': '5 days ago'},
#  {'Channel': 'YRF',
#   'Title': 'can’t take your eyes off #ghungroo #war #hrithikroshan #vaanikapoor #dance #yrfshorts #party #song',
#   'Views': '88K views',
#   'Post-Time': '6 days ago'},
#  {'Channel': 'YRF',
#   'Title': "when you can't stop thinking about them | #tujahaan #saifalikhan #preityzinta #sadsong #yrfshorts",
#   'Views': '48K views',
#   'Post-Time': '7 days ago'},
#  {'Channel': 'YRF',
#   'Title': 'The OG Proposal #tashan #akshaykumar #kareenakapoor #yrfshorts #bestdialogue #love #pyaar #proposal',
#   'Views': '81K views',
#   'Post-Time': '8 days ago'},
#  {'Channel': 'YRF',
#   'Title': 'Heart Touching❤️ #tujhmeinrabdikhtahai #rabnebanadijodi #shahrukhkhan #anushkasharma #yrfshorts #yrf',
#   'Views': '106K views',
#   'Post-Time': '9 days ago'},
#  {'Channel': 'YRF',
#   'Title': 'That moment of realization in love | #ishaqzaade #parineetichopra #arjunkapoor #yrfshorts #lyrics',
#   'Views': '111K views',
#   'Post-Time': '10 days ago'},
#  {'Channel': 'YRF',
#   'Title': '🔥 cracking moves | Tera Laal Rangi | #jayeshbhaijordaar #ranveersingh #yrfshorts #yrf #dance #song',
#   'Views': '84K views',
#   'Post-Time': '11 days ago'},
#  {'Channel': 'YRF',
#   'Title': 'This song made it to our hearts #makhmali #samratprithviraj #akshaykumar #manushichillar #yrfshorts',
#   'Views': '97K views',
#   'Post-Time': '12 days ago'},
#  {'Channel': 'YRF',
#   'Title': '💯Lyrics + 💯Location = 💯💯Song | #DekhaEkKhwab #Silsila #yrf #yrfshorts #oldsongs #evergreenhits',
#   'Views': '80K views',
#   'Post-Time': '13 days ago'},
#  ...]

# %%
# use pandas to convert list of dictionaries to dataframe
video_df = pd.DataFrame.from_dict(video_info_list)
print(video_df.shape[0])
video_df.head()
# Out:
# 1390
#     Channel                                              Title       Views  \
# 0  T-Series  Tu Banke Hawa - Dhokha: Round D Corner | R. Ma...  754K views
# 1  T-Series  Vikram In Action: Vikram Vedha | Saif Ali Khan...  737K views
# 2  T-Series  Thank God (Trailer Screening) Ft. Sidharth Mal...  219K views
# 3  T-Series  Dhokha: Round D Corner | Dialogue Promo 01: Te...  117K views
# 4  T-Series  #KatrinaKaif #AkshayKumar - Teri Galliyon Se #...  178K views
#
#       Post-Time
# 0  12 hours ago
# 1  15 hours ago
# 2  17 hours ago
# 3     1 day ago
# 4     1 day ago

# %%
import re

incorrect_views = video_df[video_df['Views'].str.find("ago") != -1]

views_cleaned_df = video_df[video_df['Views'].str.find("ago") == -1]

views_cleaned_df
# Out:
#          Channel                                              Title  \
# 0       T-Series  Tu Banke Hawa - Dhokha: Round D Corner | R. Ma...
# 1       T-Series  Vikram In Action: Vikram Vedha | Saif Ali Khan...
# 2       T-Series  Thank God (Trailer Screening) Ft. Sidharth Mal...
# 3       T-Series  Dhokha: Round D Corner | Dialogue Promo 01: Te...
# 4       T-Series  #KatrinaKaif #AkshayKumar - Teri Galliyon Se #...
# ...          ...                                                ...
# 1385  Katy Perry  Katy Perry, Darius Rucker - Only Love (Live Fr...
# 1386  Katy Perry  Katy Perry - Never Really Over/Not The End Of ...
# 1387  Katy Perry  Katy Perry, Tiësto, Aitana - Resilient (Tiësto...
# 1388  Katy Perry  Katy Perry, Tiësto - Resilient (ft. Aitana) (T...
# 1389  Katy Perry         Katy Perry - Teary Eyes (Behind The Smile)
#
#            Views     Post-Time
# 0     754K views  12 hours ago
# 1     737K views  15 hours ago
# 2     219K views  17 hours ago
# 3     117K views     1 day ago
# 4     178K views     1 day ago
# ...          ...           ...
# 1385  1.2M views    1 year ago
# 1386  2.3M views    1 year ago
# 1387  9.6M views    1 year ago
# 1388  2.8M views    1 year ago
# 1389  2.6M views   2 years ago
#
# [1308 rows x 4 columns]

# %%
incorrect_time = views_cleaned_df[views_cleaned_df['Post-Time'].str.find("views") != -1]

cleaned_df = views_cleaned_df[views_cleaned_df['Post-Time'].str.find("views") == -1]

print(cleaned_df.shape[0])

cleaned_df.head()
# Out:
# 1304
#     Channel                                              Title       Views  \
# 0  T-Series  Tu Banke Hawa - Dhokha: Round D Corner | R. Ma...  754K views
# 1  T-Series  Vikram In Action: Vikram Vedha | Saif Ali Khan...  737K views
# 2  T-Series  Thank God (Trailer Screening) Ft. Sidharth Mal...  219K views
# 3  T-Series  Dhokha: Round D Corner | Dialogue Promo 01: Te...  117K views
# 4  T-Series  #KatrinaKaif #AkshayKumar - Teri Galliyon Se #...  178K views
#
#       Post-Time
# 0  12 hours ago
# 1  15 hours ago
# 2  17 hours ago
# 3     1 day ago
# 4     1 day ago

# %%
final_df = cleaned_df[cleaned_df['Views'].str.find("watching") == -1]
final_df.head()
# Out:
#     Channel                                              Title       Views  \
# 0  T-Series  Tu Banke Hawa - Dhokha: Round D Corner | R. Ma...  754K views
# 1  T-Series  Vikram In Action: Vikram Vedha | Saif Ali Khan...  737K views
# 2  T-Series  Thank God (Trailer Screening) Ft. Sidharth Mal...  219K views
# 3  T-Series  Dhokha: Round D Corner | Dialogue Promo 01: Te...  117K views
# 4  T-Series  #KatrinaKaif #AkshayKumar - Teri Galliyon Se #...  178K views
#
#       Post-Time
# 0  12 hours ago
# 1  15 hours ago
# 2  17 hours ago
# 3     1 day ago
# 4     1 day ago

# %%
# current time
timestamp = datetime.datetime.now()

# this variable holds a string comprised of the current year, month, and day 
year_month_day = str(timestamp.year) + '_' + str(timestamp.month) + '_' + str(timestamp.day)

# save dataframe as csv file, name file based on the date it was created
final_df.to_csv(f"video_info_{year_month_day}.csv", index=False)

# %%
browser.quit()
